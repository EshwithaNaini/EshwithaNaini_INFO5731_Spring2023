# %% [markdown]
# <a href="https://colab.research.google.com/github/EshwithaNaini/EshwithaNaini_INFO5731_Spring2023/blob/main/In_class_exercise_02_02072023_Eshwitha_(1)_(3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The second In-class-exercise (02/07/2023, 40 points in total)

# %% [markdown]
# The purpose of this exercise is to understand users' information needs, then collect data from different sources for analysis.

# %% [markdown]
# Question 1 (10 points): Describe an interesting research question (or practical question) you have in mind, what kind of data should be collected to answer the question(s)? How many data needed for the analysis? The detail steps for collecting and save the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):
'''
What is the relationship between high school students' levels of physical exercise and their academic performance? 
is an intriguing study question that comes to mind.

The type of information required to respond to this query would be:

High school students' levels of physical activity can be measured via surveys or wearable fitness trackers.
Information about high school students' academic performance that can be found in school records or by administering standardized examinations.
For the analysis, between 500 and 1000 data points would be required. 
The analysis can be more reliable the more data points there are.


'''

# %% [markdown]
# Question 2 (10 points): Write python code to collect 1000 data samples you discussed above.

# %%
# You code here (Please add comments in the code):

import csv
import random

# Physical activity levels of high school students (assumed to be a scale of 1-10)
activity_level = [random.randint(1, 10) for i in range(1000)]

# Academic performance data of high school students (assumed to be a scale of 0-100)
academicPerformance = [random.randint(0, 100) for i in range(1000)]

# Combine the data into a list of tuples
dt = list(zip(activity_level, academicPerformance))
print(dt)
# Out:
# [(7, 17), (8, 97), (7, 82), (2, 58), (3, 79), (1, 31), (2, 82), (9, 53), (4, 57), (9, 4), (5, 11), (6, 34), (8, 27), (7, 87), (8, 16), (4, 13), (2, 27), (4, 58), (1, 30), (9, 37), (8, 94), (1, 5), (6, 38), (10, 8), (9, 14), (10, 76), (8, 47), (2, 59), (10, 37), (4, 24), (8, 7), (7, 26), (10, 87), (2, 2), (2, 77), (7, 2), (1, 71), (6, 27), (1, 58), (4, 12), (2, 4), (8, 80), (10, 51), (7, 82), (10, 76), (8, 61), (5, 7), (4, 65), (7, 92), (7, 92), (6, 35), (8, 19), (10, 33), (1, 6), (5, 59), (2, 51), (6, 46), (8, 38), (8, 50), (1, 5), (2, 77), (4, 4), (9, 7), (7, 33), (8, 20), (9, 61), (7, 43), (5, 5), (2, 82), (7, 39), (8, 44), (8, 6), (6, 73), (5, 14), (6, 2), (10, 19), (7, 26), (2, 28), (10, 15), (1, 1), (8, 25), (2, 66), (8, 16), (2, 0), (10, 88), (10, 46), (8, 53), (5, 48), (3, 79), (10, 36), (4, 36), (3, 71), (6, 86), (3, 51), (8, 16), (8, 27), (10, 38), (5, 17), (8, 89), (3, 26), (4, 81), (10, 70), (9, 7), (3, 89), (8, 9), (8, 77), (2, 57), (8, 81), (10, 34), (6, 62), (9, 7), (6,
# ...

# %% [markdown]
# Question 3 (10 points): Write python code to collect 1000 articles from Google Scholar (https://scholar.google.com/), Microsoft Academic (https://academic.microsoft.com/home), or CiteSeerX (https://citeseerx.ist.psu.edu/index), or Semantic Scholar (https://www.semanticscholar.org/), or ACM Digital Libraries (https://dl.acm.org/) with the keyword "information retrieval". The articles should be published in the last 10 years (2012-2022).
#
# The following information of the article needs to be collected:
#
# (1) Title
#
# (2) Venue/journal/conference being published
#
# (3) Year
#
# (4) Authors
#
# (5) Abstract

# %%
# You code here (Please add comments in the code):
import json as j
import urllib.request as request
from bs4 import BeautifulSoup as beauty

with request.urlopen('https://api.semanticscholar.org/v1/paper/10.1145/2488388.2488414') as fileread:
    pg = fileread.read()
    sp = beauty(pg)
    print(sp.p.text)
    with open('output.txt', 'w') as filewrite:
        j.dump(sp.p.text, filewrite)
# Out:
# {"abstract":"In this paper we analyze a crowdsourcing system consisting of a set of users and a set of binary choice questions. Each user has an unknown, fixed, reliability that determines the user's error rate in answering questions. The problem is to determine the truth values of the questions solely based on the user answers. Although this problem has been studied extensively, theoretical error bounds have been shown only for restricted settings: when the graph between users and questions is either random or complete. In this paper we consider a general setting of the problem where the user--question graph can be arbitrary. We obtain bounds on the error rate of our algorithm and show it is governed by the expansion of the graph. We demonstrate, using several synthetic and real datasets, that our algorithm outperforms the state of the art.","arxivId":null,"authors":[{"authorId":"1923209","name":"Nilesh N. Dalvi","url":"https://www.semanticscholar.org/author/1923209"},{"authorId":"3
# ...

# %% [markdown]
# Question 4 (10 points): Write python code to collect 1000 posts from Twitter, or Facebook, or Instagram. You can either use hashtags, keywords, user_name, user_id, or other information to collect the data.
#
# The following information needs to be collected:
#
# (1) User_name
#
# (2) Posted time
#
# (3) Text

# %%
# You code here (Please add comments in the code):

import os
import tweepy as tw
import pandas as pd

consumerkey= '2Em7SxlX9jPMfL4x97r3zMO0x'
consumersecret= 'sVbJzekKuiAgq83Y7gCwNVbSowqQokGVzWexKHl2cXIPceWtSd'
accesstoken= '1439767876962029572-uUMt8oWRyzj9ilE5zk4uYbL93sCMPT'
accesstokensecret= 'oydIGymn9bS767FVEMawE9GyGAnMmBJfaY2XXKmHnmliF'

auth = tw.OAuthHandler(consumerkey, consumersecret)
auth.set_access_token(accesstoken, accesstokensecret)
api = tw.API(auth, wait_on_rate_limit=True)

# Defining the search query and the date range
search_words = "#climatechange"
date_since = "2021-01-01"

# Convert date to tweet ID
tweets = api.search_tweets(q=search_words, tweet_mode='extended', count=1)
since_id = tweets[0].id_str

# Collecting the tweets using Cursor object
tweets = tw.Cursor(api.search_tweets,
                   q=search_words,
                   lang="en",
                   tweet_mode='extended',
                   count=100,
                   max_id=str(int(since_id)-1)).items(1000)

# Extracting the tweet text from the tweets object
tweet_texts = [tweet.full_text for tweet in tweets]
print(tweet_texts)
# Out:
# ['@JustStop_Oil "mitigate extreme suffering"  ... HUH? WHERE? World Presently In An Era Of Unusually Low Weather Disasters \nhttps://t.co/NLy4myc4gK #climatechange #climatebrawl #ClimateCrisis #ClimateEmergency #globalwarming #USPolitics #auspol #climatechangeisreal #qanda #IPCC #earthday', 'RT @MicheleLapini: #Drought in Italy, again\n\n#PoRiver hydrometric levels are back to summer levels, in some areas it has worse conditions t…', 'RT @lestak: @INSTAAR just released the 2/14/23 real time SWE report. Percent of 2001-2021 average ranges between 140-250+%. Check it out! W…', 'RT @JustStop_Oil: A short and sweet message to supporters of Just Stop Oil from comedian and activist, @markthomasinfo ✊🦺\n\n#CivilResistance…', 'Not mentioning yaws when planting is called demagogy. Not accounting for the CO2 released and that no longer absorbed is called ignorance. Willing to do numbers? Join above 52,000 people, so far, who know how to adapt to #ClimateChange: with more trees. https://t.co/On
# ...
